# %% [markdown]
# # Cluster the data and visualize
# Following [this guide](https://www.askpython.com/python/examples/plot-k-means-clusters-python)

# %%
# !pip install scikit-learn matplotlib mplcursors ipympl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in /home/lev/.local/lib/python3.10/site-packages (1.2.2)
# Requirement already satisfied: matplotlib in /home/lev/.local/lib/python3.10/site-packages (3.7.1)
# Requirement already satisfied: mplcursors in /home/lev/.local/lib/python3.10/site-packages (0.5.2)
# Requirement already satisfied: ipympl in /home/lev/.local/lib/python3.10/site-packages (0.9.3)
# Requirement already satisfied: numpy>=1.17.3 in /home/lev/.local/lib/python3.10/site-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in /home/lev/.local/lib/python3.10/site-packages (from scikit-learn) (1.9.1)
# Requirement already satisfied: joblib>=1.1.1 in /home/lev/.local/lib/python3.10/site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/lev/.local/lib/python3.10/site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/lev/.local/lib/python3.10/site-packages (from matplotlib) (1.0.6)
# Requirement already satisfied: cycler>=0.10 in /home/lev/.local/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/lev/.local/lib/python3.10/site-packages (from matplotlib) (4.37.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/lev/.local/lib/python3.10/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /home/lev/.local/lib/python3.10/site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /home/lev/.local/lib/python3.10/site-packages (from matplotlib) (10.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /home/lev/.local/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: ipython<9 in /home/lev/.local/lib/python3.10/site-packages (from ipympl) (8.5.0)
# Requirement already satisfied: ipython-genutils in /usr/lib/python3/dist-packages (from ipympl) (0.2.0)
# Requirement already satisfied: traitlets<6 in /home/lev/.local/lib/python3.10/site-packages (from ipympl) (5.3.0)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in /home/lev/.local/lib/python3.10/site-packages (from ipympl) (8.1.0)
# Requirement already satisfied: backcall in /home/lev/.local/lib/python3.10/site-packages (from ipython<9->ipympl) (0.2.0)
# Requirement already satisfied: decorator in /usr/lib/python3/dist-packages (from ipython<9->ipympl) (4.4.2)
# Requirement already satisfied: jedi>=0.16 in /home/lev/.local/lib/python3.10/site-packages (from ipython<9->ipympl) (0.18.1)
# Requirement already satisfied: matplotlib-inline in /home/lev/.local/lib/python3.10/site-packages (from ipython<9->ipympl) (0.1.6)
# Requirement already satisfied: pickleshare in /home/lev/.local/lib/python3.10/site-packages (from ipython<9->ipympl) (0.7.5)
# Requirement already satisfied: prompt-toolkit<3.1.0,>3.0.1 in /home/lev/.local/lib/python3.10/site-packages (from ipython<9->ipympl) (3.0.31)
# Requirement already satisfied: pygments>=2.4.0 in /usr/lib/python3/dist-packages (from ipython<9->ipympl) (2.11.2)
# Requirement already satisfied: stack-data in /home/lev/.local/lib/python3.10/site-packages (from ipython<9->ipympl) (0.5.0)
# Requirement already satisfied: pexpect>4.3 in /usr/lib/python3/dist-packages (from ipython<9->ipympl) (4.8.0)
# Requirement already satisfied: comm>=0.1.3 in /home/lev/.local/lib/python3.10/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (0.1.4)
# Requirement already satisfied: widgetsnbextension~=4.0.7 in /home/lev/.local/lib/python3.10/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (4.0.8)
# Requirement already satisfied: jupyterlab-widgets~=3.0.7 in /home/lev/.local/lib/python3.10/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (3.0.8)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/lev/.local/lib/python3.10/site-packages (from jedi>=0.16->ipython<9->ipympl) (0.8.3)
# Requirement already satisfied: wcwidth in /home/lev/.local/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>3.0.1->ipython<9->ipympl) (0.2.5)
# Requirement already satisfied: executing in /home/lev/.local/lib/python3.10/site-packages (from stack-data->ipython<9->ipympl) (1.0.0)
# Requirement already satisfied: asttokens in /home/lev/.local/lib/python3.10/site-packages (from stack-data->ipython<9->ipympl) (2.0.8)
# Requirement already satisfied: pure-eval in /home/lev/.local/lib/python3.10/site-packages (from stack-data->ipython<9->ipympl) (0.2.2)
#
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip

# %%
N_CLUSTERS = 10

# %%
#Importing required modules
from typing import List, Tuple
from sklearn.datasets import load_digits
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import numpy as np
import json

file_path = f"data_store/embeddings_seed_69420_size_1000.json"
embeddings: List[Tuple[str, List[float]]] = json.load(open(file_path, "r"))
 
#Load Data
# data = load_digits().data
data = np.array([e[1] for e in embeddings])
pca = PCA(2)
 
#Transform the data
df = pca.fit_transform(data)
 
#Import KMeans module
from sklearn.cluster import KMeans
 
#Initialize the class object
kmeans = KMeans(n_clusters= N_CLUSTERS)
 
#predict the labels of clusters.
label = kmeans.fit_predict(df)
 
#Getting unique labels
u_labels = np.unique(label)
# Out:
# /home/lev/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# !pip install ipywidgets --upgrade
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ipywidgets in /home/lev/.local/lib/python3.10/site-packages (8.1.0)
# Requirement already satisfied: comm>=0.1.3 in /home/lev/.local/lib/python3.10/site-packages (from ipywidgets) (0.1.4)
# Requirement already satisfied: ipython>=6.1.0 in /home/lev/.local/lib/python3.10/site-packages (from ipywidgets) (8.5.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/lev/.local/lib/python3.10/site-packages (from ipywidgets) (5.3.0)
# Requirement already satisfied: widgetsnbextension~=4.0.7 in /home/lev/.local/lib/python3.10/site-packages (from ipywidgets) (4.0.8)
# Requirement already satisfied: jupyterlab-widgets~=3.0.7 in /home/lev/.local/lib/python3.10/site-packages (from ipywidgets) (3.0.8)
# Requirement already satisfied: backcall in /home/lev/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: decorator in /usr/lib/python3/dist-packages (from ipython>=6.1.0->ipywidgets) (4.4.2)
# Requirement already satisfied: jedi>=0.16 in /home/lev/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.18.1)
# Requirement already satisfied: matplotlib-inline in /home/lev/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.6)
# Requirement already satisfied: pickleshare in /home/lev/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit<3.1.0,>3.0.1 in /home/lev/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.31)
# Requirement already satisfied: pygments>=2.4.0 in /usr/lib/python3/dist-packages (from ipython>=6.1.0->ipywidgets) (2.11.2)
# Requirement already satisfied: stack-data in /home/lev/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.5.0)
# Requirement already satisfied: pexpect>4.3 in /usr/lib/python3/dist-packages (from ipython>=6.1.0->ipywidgets) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/lev/.local/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: wcwidth in /home/lev/.local/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>3.0.1->ipython>=6.1.0->ipywidgets) (0.2.5)
# Requirement already satisfied: executing in /home/lev/.local/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (1.0.0)
# Requirement already satisfied: asttokens in /home/lev/.local/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.8)
# Requirement already satisfied: pure-eval in /home/lev/.local/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from asttokens->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
#
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip

# %%
# %matplotlib inline
# %matplotlib ipympl

from mplcursors import cursor
import mplcursors
from matplotlib.text import Annotation

# fig, ax = plt.subplots()

# for i in range(len(df)):
# 		np.random.seed(label[i])
# 		ax.scatter(df[i , 0] , df[i , 1] , label = f"Cluster {i}", color = np.random.rand(3,))
colors = np.random.rand(N_CLUSTERS, 3)
scs = []
# for i in range (len(df[:100])):
fig, ax = plt.subplots()
for i in np.random.choice(np.arange(len(df)), size=500):
    sc = ax.scatter(df[i, 0], df[i, 1], label=embeddings[i][0], color=colors[label[i]])
    scs.append(sc)

ax.set_title("KMeans Clustering")
crs = mplcursors.cursor(ax,hover=True)

crs.connect("add", lambda sel: sel.annotation.set_text(sel.annotation._text))#embeddings[sel.index][0]))#, sel.target[0], sel.target[1])))
# plt.show()
# for l in label:
#     mask = label == l
#     sc = ax.scatter(df[mask, 0], df[mask, 1], label=f"Cluster {l}", color=np.random.rand(3,))
#     scs.append(sc)
def on_plot_hover(event):
    # Iterating over each data member plotted
    return 
    for curve in sc.get_lines():
        # Searching which data member corresponds to current mouse position
        if curve.contains(event)[0]:
            print("over %s" % curve.get_gid())
            
fig.canvas.mpl_connect('motion_notify_event', on_plot_hover)
# Out:
# 19
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# /home/lev/.local/lib/python3.10/site-packages/mplcursors/_mplcursors.py:421: UserWarning: Glyph 10757 (\N{N-ARY SQUARE INTERSECTION OPERATOR}) missing from current font.
#   ann.update_positions(renderer)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/ipympl/backend_nbagg.py:279, in Canvas._handle_message(self, object, content, buffers)
#     276     self.manager.handle_json(content)
#     278 else:
# --> 279     self.manager.handle_json(content)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/backends/backend_webagg_core.py:462, in FigureManagerWebAgg.handle_json(self, content)
#     461 def handle_json(self, content):
# --> 462     self.canvas.handle_event(content)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/backends/backend_webagg_core.py:266, in FigureCanvasWebAggCore.handle_event(self, event)
#     263 e_type = event['type']
#     264 handler = getattr(self, 'handle_{0}'.format(e_type),
#     265                   self.handle_unknown_event)
# --> 266 return handler(event)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/backends/backend_webagg_core.py:297, in FigureCanvasWebAggCore._handle_mouse(self, event)
#     294 guiEvent = event.get('guiEvent')
#     295 if e_type in ['button_press', 'button_release']:
#     296     MouseEvent(e_type + '_event', self, x, y, button,
# --> 297                modifiers=modifiers, guiEvent=guiEvent)._process()
#     298 elif e_type == 'dblclick':
#     299     MouseEvent('button_press_event', self, x, y, button, dblclick=True,
#     300                modifiers=modifiers, guiEvent=guiEvent)._process()
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/backend_bases.py:1263, in Event._process(self)
#    1261 def _process(self):
#    1262     """Generate an event with name ``self.name`` on ``self.canvas``."""
# -> 1263     self.canvas.callbacks.process(self.name, self)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/cbook/__init__.py:309, in CallbackRegistry.process(self, s, *args, **kwargs)
#     307 except Exception as exc:
#     308     if self.exception_handler is not None:
# --> 309         self.exception_handler(exc)
#     310     else:
#     311         raise
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/cbook/__init__.py:96, in _exception_printer(exc)
#      94 def _exception_printer(exc):
#      95     if _get_running_interactive_framework() in ["headless", None]:
# ---> 96         raise exc
#      97     else:
#      98         traceback.print_exc()
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/cbook/__init__.py:304, in CallbackRegistry.process(self, s, *args, **kwargs)
#     302 if func is not None:
#     303     try:
# --> 304         func(*args, **kwargs)
#     305     # this does not capture KeyboardInterrupt, SystemExit,
#     306     # and GeneratorExit
#     307     except Exception as exc:
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/offsetbox.py:1550, in DraggableBase.on_release(self, event)
#    1549 def on_release(self, event):
# -> 1550     if self._check_still_parented() and self.got_artist:
#    1551         self.finalize_offset()
#    1552         self.got_artist = False
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/offsetbox.py:1560, in DraggableBase._check_still_parented(self)
#    1558 def _check_still_parented(self):
#    1559     if self.ref_artist.figure is None:
# -> 1560         self.disconnect()
#    1561         return False
#    1562     else:
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/offsetbox.py:1568, in DraggableBase.disconnect(self)
#    1566 """Disconnect the callbacks."""
#    1567 for cid in self.cids:
# -> 1568     self.canvas.mpl_disconnect(cid)
#    1569 try:
#    1570     c1 = self._c1
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/offsetbox.py:1517, in DraggableBase.<lambda>(self)
#    1509     self.cids = [
#    1510         self.canvas.callbacks._connect_picklable(
#    1511             'pick_event', self.on_pick),
#    1512         self.canvas.callbacks._connect_picklable(
#    1513             'button_release_event', self.on_release),
#    1514     ]
#    1516 # A property, not an attribute, to maintain picklability.
# -> 1517 canvas = property(lambda self: self.ref_artist.figure.canvas)
#    1519 def on_motion(self, evt):
#    1520     if self._check_still_parented() and self.got_artist:
#
# AttributeError: 'NoneType' object has no attribute 'canvas'
# /home/lev/.local/lib/python3.10/site-packages/mplcursors/_mplcursors.py:421: UserWarning: Glyph 10757 (\N{N-ARY SQUARE INTERSECTION OPERATOR}) missing from current font.
#   ann.update_positions(renderer)
# /home/lev/.local/lib/python3.10/site-packages/ipympl/backend_nbagg.py:279: UserWarning: Glyph 10757 (\N{N-ARY SQUARE INTERSECTION OPERATOR}) missing from current font.
#   self.manager.handle_json(content)
